# %%
# %matplotlib notebook
import time
from pymongo import MongoClient 
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from datetime import datetime
from bson.objectid import ObjectId
from matplotlib.animation import FuncAnimation
from collections import Counter

# %%
hostip = "10.192.41.222"
client = MongoClient(
        host=f'{hostip}',
        port=27017
    )
db = client["awas_db"]
violation_col = db["violation"]

print(violation_col.count_documents({}))

for doc in violation_col.find().limit(5):
    print(doc)
# Out:
# 1473
# {'_id': '2024-01-01_PI 9', 'car_plate': 'PI 9', 'date': '2024-01-01', 'violations': [{'violation_id': 'd2b1c0c4-1320-44e9-8bd4-3a3b21a64ab3', 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:08:02', 'timestamp_end': '2024-01-01T08:08:26.478501', 'recorded_speed': 150.0, 'speed_limit': 110.0}, {'violation_id': 'd7062be2-7b3e-4985-beea-911e6300e884', 'type': 'average', 'camera_id_start': 2, 'camera_id_end': 3, 'timestamp_start': '2024-01-01T08:08:26.478501', 'timestamp_end': '2024-01-01T08:08:53.620450', 'recorded_speed': 133.33333333333334, 'speed_limit': 110.0}, {'violation_id': '06b1430f-6ca1-4b0d-b2c6-65cbb308c41c', 'type': 'instant', 'camera_id_start': 1, 'camera_id_end': 1, 'timestamp_start': '2024-01-01T08:08:02', 'timestamp_end': '2024-01-01T08:08:02', 'recorded_speed': 154.0, 'speed_limit': 110.0}, {'violation_id': '93318b12-8237-4a04-a6fe-7805c448d009', 'type': 'instant', 'camera_id_start': 2, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:08:26.478501', 'timestamp_end': '2024-01-01T08:08:26.478501', 'recorded_speed': 140.9, 'speed_limit': 110.0}, {'violation_id': '59ef7901-f9ce-49d1-836a-eb2b2fe5edc7', 'type': 'instant', 'camera_id_start': 3, 'camera_id_end': 3, 'timestamp_start': '2024-01-01T08:08:53.620450', 'timestamp_end': '2024-01-01T08:08:53.620450', 'recorded_speed': 134.3, 'speed_limit': 90.0}, {'violation_id': 'c9087ae2-f150-4972-91fe-5df0bce9beb9', 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:08:02', 'timestamp_end': '2024-01-01T08:08:26.478501', 'recorded_speed': 150.0, 'speed_limit': 110.0}, {'violation_id': '2d1cb8d0-ef98-42ed-b9b0-59d0ce2095a3', 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:08:02', 'timestamp_end': '2024-01-01T08:08:26.478501', 'recorded_speed': 150.0, 'speed_limit': 110.0}, {'violation_id': '8b90a2f1-00e1-41e4-ac2a-21788559ab45', 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:08:02', 'timestamp_end': '2024-01-01T08:08:26.478501', 'recorded_speed': 150.0, 'speed_limit': 110.0}, {'violation_id': 'fa6b735c-bf2b-47d0-8d02-e604018db6ab', 'type': 'average', 'camera_id_start': 2, 'camera_id_end': 3, 'timestamp_start': '2024-01-01T08:08:26.478501', 'timestamp_end': '2024-01-01T08:08:53.620450', 'recorded_speed': 133.33333333333334, 'speed_limit': 110.0}, {'violation_id': 'a501f74d-2ffe-4f30-bb91-38954cf7fff6', 'type': 'average', 'camera_id_start': 2, 'camera_id_end': 3, 'timestamp_start': '2024-01-01T08:08:26.478501', 'timestamp_end': '2024-01-01T08:08:53.620450', 'recorded_speed': 133.33333333333334, 'speed_limit': 110.0}, {'violation_id': 'da41f7c8-014f-4e1d-89dd-54d7bc46402a', 'type': 'average', 'camera_id_start': 2, 'camera_id_end': 3, 'timestamp_start': '2024-01-01T08:08:26.478501', 'timestamp_end': '2024-01-01T08:08:53.620450', 'recorded_speed': 133.33333333333334, 'speed_limit': 110.0}, {'violation_id': 'f91aaf86-8a41-42b7-8eee-747abed22d82', 'type': 'instant', 'camera_id_start': 1, 'camera_id_end': 1, 'timestamp_start': '2024-01-01T08:08:02', 'timestamp_end': '2024-01-01T08:08:02', 'recorded_speed': 154.0, 'speed_limit': 110.0}, {'violation_id': '15ec746c-42ef-42a6-b184-5b2a63641d5c', 'type': 'instant', 'camera_id_start': 2, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:08:26.478501', 'timestamp_end': '2024-01-01T08:08:26.478501', 'recorded_speed': 140.9, 'speed_limit': 110.0}, {'violation_id': '1028c8fc-7efa-4511-a719-657a0573f258', 'type': 'instant', 'camera_id_start': 3, 'camera_id_end': 3, 'timestamp_start': '2024-01-01T08:08:53.620450', 'timestamp_end': '2024-01-01T08:08:53.620450', 'recorded_speed': 134.3, 'speed_limit': 90.0}], 'total_violations': 14}
# {'_id': '2024-01-01_MZ 242', 'car_plate': 'MZ 242', 'date': '2024-01-01', 'violations': [{'violation_id': '94c0152b-c356-489f-b1a3-b58297402145', 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:13:11', 'timestamp_end': '2024-01-01T08:13:34.452533', 'recorded_speed': 156.52173913043478, 'speed_limit': 110.0}, {'violation_id': '164f6d30-d591-43bd-9753-2efe736a6a9c', 'type': 'instant', 'camera_id_start': 1, 'camera_id_end': 1, 'timestamp_start': '2024-01-01T08:13:11', 'timestamp_end': '2024-01-01T08:13:11', 'recorded_speed': 143.3, 'speed_limit': 110.0}, {'violation_id': 'efc4a18b-6a33-4cda-bbb7-ab4a4200597d', 'type': 'instant', 'camera_id_start': 2, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:13:34.452533', 'timestamp_end': '2024-01-01T08:13:34.452533', 'recorded_speed': 152.6, 'speed_limit': 110.0}, {'violation_id': '722e946e-87f3-4bfe-8624-6241f786a485', 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:13:11', 'timestamp_end': '2024-01-01T08:13:34.452533', 'recorded_speed': 156.52173913043478, 'speed_limit': 110.0}, {'violation_id': 'd2de7007-c29b-44cc-88df-95b259842969', 'type': 'instant', 'camera_id_start': 1, 'camera_id_end': 1, 'timestamp_start': '2024-01-01T08:13:11', 'timestamp_end': '2024-01-01T08:13
 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:13:07', 'timestamp_end': '2024-01-01T08:13:38.833509', 'recorded_speed': 116.12903225806451, 'speed_limit': 110.0}, {'violation_id': 'f349751a-b83d-4f75-b72b-801eda66a12e', 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:13:07', 'timestamp_end': '2024-01-01T08:13:38.833509', 'recorded_speed': 116.12903225806451, 'speed_limit': 110.0}, {'violation_id': '4e8ec91f-de26-47f5-8498-5602ef69f953', 'type': 'instant', 'camera_id_start': 3, 'camera_id_end': 3, 'timestamp_start': '2024-01-01T08:14:11.741826', 'timestamp_end': '2024-01-01T08:14:11.741826', 'recorded_speed': 109.8, 'speed_limit': 90.0}], 'total_violations': 7}
# {'_id': '2024-01-01_CJP 278', 'car_plate': 'CJP 278', 'date': '2024-01-01', 'violations': [{'violation_id': '109b31f3-d4dc-4a2a-8e24-3696652c8786', 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:00:02', 'timestamp_end': '2024-01-01T08:00:31.515912', 'recorded_speed': 124.13793103448276, 'speed_limit': 110.0}, {'violation_id': 'a6677634-82da-45e5-96ec-64a1d0d2cdf2', 'type': 'average', 'camera_id_start': 2, 'camera_id_end': 3, 'timestamp_start': '2024-01-01T08:00:31.515912', 'timestamp_end': '2024-01-01T08:01:02.795526', 'recorded_speed': 116.12903225806451, 'speed_limit': 110.0}, {'violation_id': '531ccefe-6f11-4e6e-bd99-fddcdd034f3e', 'type': 'instant', 'camera_id_start': 1, 'camera_id_end': 1, 'timestamp_start': '2024-01-01T08:00:02', 'timestamp_end': '2024-01-01T08:00:02', 'recorded_speed': 125.2, 'speed_limit': 110.0}, {'violation_id': 'cf5ee550-dfb8-4dd7-a7a0-6735e3af82e5', 'type': 'instant', 'camera_id_start': 2, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:00:31.515912', 'timestamp_end': '2024-01-01T08:00:31.515912', 'recorded_speed': 117.6, 'speed_limit': 110.0}, {'violation_id': '24e1600e-d3a8-4b81-bef2-be7007abe058', 'type': 'instant', 'camera_id_start': 3, 'camera_id_end': 3, 'timestamp_start': '2024-01-01T08:01:02.795526', 'timestamp_end': '2024-01-01T08:01:02.795526', 'recorded_speed': 118.6, 'speed_limit': 90.0}, {'violation_id': 'f3107418-2fb7-4c18-aa19-01499aeb50d4', 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:00:02', 'timestamp_end': '2024-01-01T08:00:31.515912', 'recorded_speed': 124.13793103448276, 'speed_limit': 110.0}, {'violation_id': '88615363-549e-4340-bdde-3aeb29ec440b', 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:00:02', 'timestamp_end': '2024-01-01T08:00:31.515912', 'recorded_speed': 124.13793103448276, 'speed_limit': 110.0}, {'violation_id': 'f3423ce9-eb81-495c-ab2f-152ab55f5e31', 'type': 'average', 'camera_id_start': 1, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:00:02', 'timestamp_end': '2024-01-01T08:00:31.515912', 'recorded_speed': 124.13793103448276, 'speed_limit': 110.0}, {'violation_id': '179bc6a8-fc98-4ff7-8e16-895860eabe90', 'type': 'average', 'camera_id_start': 2, 'camera_id_end': 3, 'timestamp_start': '2024-01-01T08:00:31.515912', 'timestamp_end': '2024-01-01T08:01:02.795526', 'recorded_speed': 116.12903225806451, 'speed_limit': 110.0}, {'violation_id': 'a08d98c5-a5aa-4bf4-a35c-40542b011f26', 'type': 'instant', 'camera_id_start': 1, 'camera_id_end': 1, 'timestamp_start': '2024-01-01T08:00:02', 'timestamp_end': '2024-01-01T08:00:02', 'recorded_speed': 125.2, 'speed_limit': 110.0}, {'violation_id': '8977b832-f007-4b5c-b879-f7fb4003797f', 'type': 'instant', 'camera_id_start': 2, 'camera_id_end': 2, 'timestamp_start': '2024-01-01T08:00:31.515912', 'timestamp_end': '2024-01-01T08:00:31.515912', 'recorded_speed': 117.6, 'speed_limit': 110.0}, {'violation_id': '2806b462-a603-47f7-b72f-54041b95df9e', 'type': 'instant', 'camera_id_start': 3, 'camera_id_end': 3, 'timestamp_start': '2024-01-01T08:01:02.795526', 'timestamp_end': '2024-01-01T08:01:02.795526', 'recorded_speed': 118.6, 'speed_limit': 90.0}], 'total_violations': 12}

# %%
# Initialize last seen _id
last_id = ObjectId.from_datetime(datetime.min)
def fetch_latest_data():
    global last_id
    new_docs = collection.find({"_id": {"$gt": last_id}}).sort("_id", 1)

    results = []
    latest_id = last_id
    for doc in new_docs:
        latest_id = max(latest_id, doc["_id"])
        for v in doc.get("violations", []):
            try:
                ts = dt_parser.parse(v["timestamp_start"])
                results.append(ts.replace(second=0, microsecond=0))  # round to minute
            except Exception as e:
                print("Error parsing timestamp:", e)

    last_id = latest_id
    return results
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Initialize last seen _id
# ----> 2 last_id = ObjectId.from_datetime(datetime.min)
#       3 def fetch_latest_data():
#       4     global last_id
#
# File /opt/conda/lib/python3.10/site-packages/bson/objectid.py:135, in ObjectId.from_datetime(cls, generation_time)
#     107 @classmethod
#     108 def from_datetime(cls: Type[ObjectId], generation_time: datetime.datetime) -> ObjectId:
#     109     """Create a dummy ObjectId instance with a specific generation time.
#     110
#     111     This method is useful for doing range queries on a field
#    (...)
#     132         as the generation time for the resulting ObjectId.
#     133     """
#     134     oid = (
# --> 135         _PACK_INT(_datetime_to_millis(generation_time) // 1000)
#     136         + b"\x00\x00\x00\x00\x00\x00\x00\x00"
#     137     )
#     138     return cls(oid)
#
# error: argument out of range

# %%
# # Real-time plotting function
# def visualize_stream(interval_sec=5):
#     # fig, ax = plt.subplots(figsize=(12, 6))

#     while True:
#         df = fetch_violation_data()
#         if df.empty:
#             print("No data yet...")
#             time.sleep(interval_sec)
#             continue

#         # Convert string/object to datetime
#         df["timestamp"] = pd.to_datetime(df["timestamp"], format='ISO8601', errors='coerce')

#         # Group by 10-second intervals
#         df.set_index("timestamp", inplace=True)
#         counts = df.resample("5s").size()

#         clear_output(wait=True)
#         plt.figure(figsize=(12, 6))
#         plt.plot(counts.index, counts.values, marker='o', linestyle='-')

#         if not counts.empty:
#             max_time = counts.idxmax()
#             max_val = counts.max()
#             min_time = counts.idxmin()
#             min_val = counts.min()
#             plt.annotate(f'Max: {max_val}', xy=(max_time, max_val), xytext=(max_time, max_val + 1),
#                          arrowprops=dict(facecolor='green'), fontsize=10)
#             plt.annotate(f'Min: {min_val}', xy=(min_time, min_val), xytext=(min_time, min_val + 1),
#                          arrowprops=dict(facecolor='red'), fontsize=10)

#         plt.title("Violations Over Time (10s)")
#         plt.xlabel("Time")
#         plt.ylabel("Number of Violations")
#         plt.grid(True)
#         plt.tight_layout()
#         plt.show()

#         time.sleep(interval_sec)

all_timestamps = []

fig, ax = plt.subplots()
line, = ax.plot([], [], 'bo-')

def update(frame):
    global all_timestamps

    # Fetch new timestamps
    new_times = fetch_latest_data()
    all_timestamps.extend(new_times)

    if not all_timestamps:
        return

    # Count and sort timestamps
    counter = Counter(all_timestamps)
    sorted_times = sorted(counter)
    counts = [counter[t] for t in sorted_times]

    ax.clear()
    ax.set_title("Violations per Arrival Time")
    ax.set_xlabel("Arrival Time")
    ax.set_ylabel("Number of Violations")
    ax.plot(sorted_times, counts, 'bo-')
    ax.tick_params(axis='x', rotation=45)

ani = FuncAnimation(fig, update, interval=60_000)  # every 60 sec
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /tmp/ipykernel_2186556/2981774818.py:69: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = FuncAnimation(fig, update, interval=60_000)  # every 60 sec
